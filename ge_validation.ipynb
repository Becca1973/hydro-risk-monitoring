# %%
import os

print(os.getcwd())
print(os.path.exists("data/preprocessed/hidro/2110_Ptuj.csv"))
print([f for f in os.listdir("data/preprocessed/hidro") if "Ptuj" in f])
# Out:
# c:\Users\rebek\IIS\project\hydro-risk-monitoring
# True
# ['2110_Ptuj.csv']

# %%
import great_expectations as gx

context = gx.get_context()

datasource_name = "hidro_fluent"
data_asset_name = "hidro_ptuj"

datasource = context.sources.add_or_update_pandas_filesystem(
    name=datasource_name,
    base_directory="data/preprocessed/hidro"
)

data_asset = datasource.add_csv_asset(
    name=data_asset_name,
    batching_regex=r"2110_Ptuj\.csv"
)

expectation_suite_name = "hidro_suite"

context.add_or_update_expectation_suite(
    expectation_suite_name=expectation_suite_name
)

asset = context.get_datasource(datasource_name).get_asset(data_asset_name)
batch_request = asset.build_batch_request()

validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=expectation_suite_name
)

validator.head()
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#    sifra             datum         datum_cet  vodostaj  pretok  \
# 0   2110  2025-05-20 10:00  2025-05-20 09:00     512.0  140.00
# 1   2110  2025-05-20 10:30  2025-05-20 09:30     508.0  137.00
# 2   2110  2025-05-20 11:00  2025-05-20 10:00     511.0     NaN
# 3   2110  2025-05-20 11:30  2025-05-20 10:30     513.0   46.70
# 4   2110  2025-05-20 12:30  2025-05-20 11:30     515.0    1.16
#
#    prvi_vv_pretok  drugi_vv_pretok  tretji_vv_pretok pretok_znacilni  \
# 0          1300.0           1580.0            1700.0     mali pretok
# 1          1300.0           1580.0            1700.0     mali pretok
# 2          1300.0           1580.0            1700.0             NaN
# 3          1300.0           1580.0            1700.0     mali pretok
# 4          1300.0           1580.0            1700.0     mali pretok
#
#    temp_vode
# 0       14.5
# 1       14.6
# 2       14.7
# 3       14.8
# 4       14.8

# %%
exclude_column_names = []

data_assistant_result = context.assistants.onboarding.run(
    validator=validator,
    exclude_column_names=exclude_column_names
)

expectation_suite = data_assistant_result.get_expectation_suite()

context.save_expectation_suite(
    expectation_suite=expectation_suite,
    expectation_suite_name=expectation_suite_name
)
# Out:
# ...
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# 'c:\\Users\\rebek\\IIS\\project\\hydro-risk-monitoring\\gx\\expectations/hidro_suite.json'

# %%
import great_expectations as gx

context = gx.get_context()

datasource_name = "weather_fluent"
data_asset_name = "weather_celje"

datasource = context.sources.add_or_update_pandas_filesystem(
    name=datasource_name,
    base_directory="data/preprocessed/weather"
)

data_asset = datasource.add_csv_asset(
    name=data_asset_name,
    batching_regex=r"CELJE\.csv"
)

expectation_suite_name = "weather_suite"

context.add_or_update_expectation_suite(
    expectation_suite_name=expectation_suite_name
)

asset = context.get_datasource(datasource_name).get_asset(data_asset_name)
batch_request = asset.build_batch_request()

validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=expectation_suite_name
)

validator.head()
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#           timestamp_utc        timestamp_local  temperature  dew_point  \
# 0   01.06.2025 0:30 UTC   01.06.2025 2:30 CEST         14.1       13.4
# 1  01.06.2025 10:00 UTC  01.06.2025 12:00 CEST         27.3       14.9
# 2  01.06.2025 11:00 UTC  01.06.2025 13:00 CEST         28.0       14.5
# 3  01.06.2025 12:00 UTC  01.06.2025 14:00 CEST         28.9       15.3
# 4  01.06.2025 12:30 UTC  01.06.2025 14:30 CEST         29.1       16.3
#
#    rel_humidity  precipitation  precipitation_1h  precipitation_12h  \
# 0            95            0.0               NaN                0.0
# 1            47            0.0               0.0                0.0
# 2            44            0.0               NaN                0.0
# 3            44            0.0               0.0                0.0
# 4            46            0.0               NaN                0.0
#
#    wind_speed  wind_direction  snow station
# ...

# %%
exclude_column_names = []

data_assistant_result = context.assistants.onboarding.run(
    validator=validator,
    exclude_column_names=exclude_column_names
)

expectation_suite = data_assistant_result.get_expectation_suite()

context.save_expectation_suite(
    expectation_suite=expectation_suite,
    expectation_suite_name=expectation_suite_name
)
# Out:
# ...
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# 'c:\\Users\\rebek\\IIS\\project\\hydro-risk-monitoring\\gx\\expectations/weather_suite.json'

# %%
checkpoint_name = "weather_checkpoint"

checkpoint = context.add_or_update_checkpoint(
    name=checkpoint_name,
    validations=[
        {
            "batch_request": batch_request,
            "expectation_suite_name": "weather_suite"
        }
    ],
)

# %%
# Run checkpoint

checkpoint_result = checkpoint.run()

# Build data docs

context.build_data_docs()
context.open_data_docs()
# Out:
# Calculating Metrics:   0%|          | 0/252 [00:00<?, ?it/s]

# %%
checkpoint_name = "hidro_checkpoint"

batch_request = asset.build_batch_request()

checkpoint = context.add_or_update_checkpoint(
    name=checkpoint_name,
    validations=[
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name
        }
    ],
)

# %%
checkpoint_result = checkpoint.run()

context.build_data_docs()
context.open_data_docs()
# Out:
# Calculating Metrics:   0%|          | 0/203 [00:00<?, ?it/s]

# %%
#ročna pravila za hidro 
validator.expect_table_row_count_to_be_between(min_value=100)

validator.expect_table_columns_to_match_set(
    column_set=[
        "sifra",
        "datum",
        "datum_cet",
        "vodostaj",
        "pretok",
        "prvi_vv_pretok",
        "drugi_vv_pretok",
        "tretji_vv_pretok",
        "pretok_znacilni",
        "temp_vode",
    ],
    exact_match=True,
)

validator.expect_column_values_to_be_unique("datum")
validator.expect_column_values_to_not_be_null("datum")
validator.expect_column_values_to_not_be_null("vodostaj")

validator.expect_column_values_to_be_between("vodostaj", min_value=0, max_value=2000)
validator.expect_column_values_to_be_between("pretok", min_value=0, max_value=5000, mostly=0.95)
validator.expect_column_values_to_be_between("temp_vode", min_value=-5, max_value=35, mostly=0.95)

validator.save_expectation_suite(discard_failed_expectations=False)
# Out:
# ...
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
validator.expect_table_row_count_to_be_between(min_value=100)

validator.expect_table_columns_to_match_set(
    column_set=[
        "timestamp_utc",
        "timestamp_local",
        "temperature",
        "dew_point",
        "rel_humidity",
        "precipitation",
        "precipitation_1h",
        "precipitation_12h",
        "wind_speed",
        "wind_direction",
        "snow",
        "station",
    ],
    exact_match=True,
)

validator.expect_column_values_to_be_unique("timestamp_utc")
validator.expect_column_values_to_not_be_null("timestamp_utc")
validator.expect_column_values_to_not_be_null("temperature")
validator.expect_column_values_to_not_be_null("station")

validator.expect_column_values_to_be_between("temperature", min_value=-40, max_value=50)
validator.expect_column_values_to_be_between("rel_humidity", min_value=0, max_value=100, mostly=0.95)
validator.expect_column_values_to_be_between("precipitation", min_value=0, max_value=500, mostly=0.95)
validator.expect_column_values_to_be_between("wind_speed", min_value=0, max_value=100, mostly=0.95)
validator.expect_column_values_to_be_between("wind_direction", min_value=0, max_value=360, mostly=0.95)

validator.save_expectation_suite(discard_failed_expectations=False)
# Out:
# ...
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
